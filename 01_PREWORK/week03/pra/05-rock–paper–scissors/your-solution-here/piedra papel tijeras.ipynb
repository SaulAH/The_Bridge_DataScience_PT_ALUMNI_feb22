# %% [markdown]
# # Piedra, papel, tijeras
#
# Vamos jugar contra nuestro ordenador al famoso juego.
#
# https://es.wikipedia.org/wiki/Piedra,_papel_o_tijera
#
# Se aconseja el uso de funciones

# %%
! pip install random
# Out:
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random

# %%
# Importa la función choice del módulo random
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list


# Asigna a una lista las 3 posibles opciones: 'piedra', 'papel' o 'tijeras'. 
lista=["piedra","papel","tijera"]

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...

import random
from math import ceil
n_partidas=[1,2,3,4,5,6,7,8]
p_max=random.choice(n_partidas)

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas
def victorias(p_max):
    if p_max == 1:
       print(p_max)
       return p_max
    else: 
        if p_max // 2 == 0:
            p_max = (p_max / 2) + 1
            return p_max
        else:
            p_max = ceil(p_max / 2 )
            return p_max

# Define una función que devuelva aleatoriamente una de las 3 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 

def j_maquina(int):
    elec=random.choice(lista)
    return elec
    


# Define una función que pregunte tu elección: 'piedra', 'papel' o 'tijeras'
# sólo debe permitir una de las 3 opciones. Esto es programación defensiva. 
# Si no es piedra, papel o tijeras sigue preguntando hasta que lo sea. 

def j_jugador(string):
    variable=input("Introduce tu elección, piedra, papel o tijera:")
    if variable in lista:
        return variable
    else:
        print("No has elegido 1 de las 3 opciones:")
        while variable not in lista:
            variable=input("Por favor lee bien, introduce piedra, papel o tijera ")
        return variable

# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano
 
def combate():
    gana_j=0
    gana_m=0
    while (gana_j< p_max) and (gana_m < p_max):
     b=j_maquina(elec)
     c=j_jugador(variable)
     if b == "piedra":
        if c =="tijera":
            gana_m =gana_m +1
            estado_part()
        else:
            gana_j =gana_j +1
            estado_part()
     elif b == "papel":
        if c =="piedra":
            gana_m =gana_m +1
            estado_part()
        else:
            gana_j =gana_j +1
            #print(gana_j)
            estado_part()
     else:
        if c =="papel":
            gana_m =gana_m +1
            estado_part()
        else:
            gana_j =gana_j +1
            estado_part()
    if gana_j > gana_m:
        return 2
    elif gana_j == gana_m:
        return 1
    else:
        return 3



# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
def estado_part():
    print("Jugador a elegido:", b, "maquina a elegido:", c )
    if gana_j > gana_m:
        print("La partida la va ganando jugador: ", gana_j)
    else:
        print("La partida la va ganando la maquina: ", gana_m)

    
# Crea dos variables que acumulen las partidas ganadas de cada participante

gana_m
gana_j

# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 

def combate():
    gana_j=0
    gana_m=0
    while (gana_j < p_max) and (gana_m < p_max):
     b=j_maquina(elec)
     c=j_jugador(variable)
     if b == "piedra":
        if c =="tijera":
            gana_m =gana_m +1
            estado_part()
        else:
            gana_j =gana_j +1
            estado_part()
     elif b == "papel":
        if c =="piedra":
            gana_m =gana_m +1
            estado_part()
        else:
            gana_j =gana_j +1
            estado_part()
     else:
        if c =="papel":
            gana_m =gana_m +1
            estado_part()
        else:
            gana_j =gana_j +1
            estado_part()
        
    if gana_j > gana_m:
        return 2
    elif gana_j == gana_m:
        return 1
    else:
        return 3
    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas
    if gana_j > gana_m:
        print("El ganador es el jugador:",gana_j)
    elif gana_j == gana_m:
        print("Han empatado:",gana_j)
    else:
        print("El ganador es el maquina:",gana_m)
# Out:
# 8

# %%
# Out:
# Gana jugador_3 1
# Gana jugador_3 2
# Gana jugador_3 3
# Gana jugador_3 4
# Gana jugador_3 5
# Gana jugador_3 6
# Gana jugador_3 7
# Gana jugador_3 8
# 8

# %%
lista=["piedra","papel","tijera"]

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...

import random
from math import ceil
n_partidas=[1,2,3,4,5,6,7,8]
p_max=random.choice(n_partidas)
#print(p_max)
victorias(p_max)
# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas
def victorias(int):
    if cpart == 1:
       #print(cpart)
       p_max=cpart
       return p_max
    else: 
        if  cpart // 2 == 0:
            p_max = (cpart/ 2) + 1
            return p_max
        else:
            p_max = ceil(cpart/ 2 )
            return p_max

def estado_part():
    print("Jugador a elegido:", b, "maquina a elegido:", c )
    if gana_j > gana_m:
        print("La partida la va ganando jugador: ", gana_j)
    else:
        print("La partida la va ganando la maquina: ", gana_m)

combate()
# Out:
# 1 4
# Jugador a elegido: piedra maquina a elegido: papel
# La partida la va ganando jugador:  8
# Jugador a elegido: piedra maquina a elegido: papel
# La partida la va ganando jugador:  8
# Jugador a elegido: piedra maquina a elegido: papel
# La partida la va ganando jugador:  8
# Jugador a elegido: piedra maquina a elegido: papel
# La partida la va ganando jugador:  8
# Jugador a elegido: piedra maquina a elegido: papel
# La partida la va ganando jugador:  8

# %%
lista=["piedra","papel","tijera"]

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...

import random
from math import ceil
n_partidas=[1,2,3,4,5,6,7,8]

#elec=0
#variable="p"
def victorias(int):
    p_max=random.choice(n_partidas)
    if p_max == 1:
       #print(p_max)
       return p_max
    else: 
        if p_max // 2 == 0:
            p_max = (p_max / 2) + 1
            return p_max
        else:
            p_max = ceil(p_max / 2 )
            return p_max

def j_maquina(int):
    elec=random.choice(lista)
    #print(elec)
    return elec

def j_jugador(string):
    variable=input("Introduce tu elección, piedra, papel o tijera:")
    if variable in lista:
        return variable
    else:
        print("No has elegido 1 de las 3 opciones:")
        while variable not in lista:
            variable=input("Por favor lee bien, introduce piedra, papel o tijera ")
        return variable
    return variable


print(a,b,c)
# Out:
# 4 tijera piedra

# %%
# Out:
# 4
# tijera
# piedra
# Gana jugador_3 1
# Gana jugador_3 2
# Gana jugador_3 3
# Gana jugador_3 4
# Gana jugador_3 5
# Gana jugador_3 6
# Gana jugador_3 7
# Gana jugador_3 8

# %% [markdown]
# # Bonus: Piedra, papel, tijeras, lagarto, spock
#
# Ahora vienen las mejoras.
#
# http://www.samkass.com/theories/RPSSL.html
#
# Se te pide que implimentes unas mejoras con respecto al simple juego previo. Además el número de partidas (que deberá ser IMPAR) se pedirá por consola hasta que se introduzca un número válido.
#
# Mejoras:
# * 5 opciones: piedra, papel, tijeras, lagarto, spock
# * El número de partidas se pide por consola
# Consejo: Reutiliza código que ya hagas utilizado

# %%
# Importa la función choice del módulo random


# Define una función que pide por teclado un número impar, hasta que no sea válido
# seguirá pidiendo


# Asigna a una lista las 5 posibles opciones. 


# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
# Esta vez se usa la función definida previamente


# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas


# Define una función que devuelva aleatoriamente una de las 5 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 



# Define una función que pregunte tu elección de entre las 5
# sólo debe permitir una de las 5 opciones. Esto es programación defensiva. 
# Si no es válida sigue preguntando hasta que lo sea. 


# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano
# Ahora hay más opciones


    
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados


    
# Crea dos variables que acumulen las partidas ganadas de cada participante


# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 


    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas

# %% [markdown]
# Si has programado con cabeza, el bonus son simples modificaciones al juego original.

# %% [markdown]
# ## Objetivos
# 1. Uso de bucle
# 2. Captura de datos por consola
# 3. Uso if-elif-else
# 4. Uso de try-except
# 5. Definición de funciones. Programación modular.
# 6. Operadores lógicos.
# 7. Imprimir por consola
# 8. Importación de módulos externos
